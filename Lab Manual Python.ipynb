# %%
#Exp 2

print("Welcome to Gulzar Group of Institutions")
# Out:
# Welcome to Gulzar Group of Institutions

# %%
#Exp 3

name = input("Enter your name:")
print("Welcome", name)
# Out:
# Enter your name: Aman
# Welcome Aman

# %%
#Exp 4

if True:
    print("Program Corrected Successfully")
# Out:
# Program Corrected Successfully

# %%
#Exp 5

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))
c = int(input("Enter third number:"))

if a>b and a>c:
    print("Largest:", a)
elif b>c:
    print("Largest:" , b)
else:
    print("Largest:", c)
# Out:
# Enter first number: 20
# Enter second number: 5
# Enter third number: 77
# Largest: 77

# %%
#Exp 6

print("1.Add 2.Subtract 3.Multply 4.Divide")
ch = int(input("Enter choice:"))
a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if ch == 1:
    print("Result:", a+b)
elif ch == 2:
    print("Result:", a-b)
elif ch == 3:
    print("Result:", a*b)
elif ch == 4:
    print("Result:", a/b)
else:
    print("Invalid choice")
# Out:
# 1.Add 2.Subtract 3.Multply 4.Divide
# Enter choice: 1
# Enter first number: 20
# Enter second number: 10
# Result: 30

# %%
#Exp 7

n = int(input("Enter terms:"))
a, b = 0, 1

for i in range(n):
    print(a, end=" ")
    a, b = b, a+b
# Out:
# Enter terms: 8
# 0 1 1 2 3 5 8 13

# %%
#Exp 8

num = int(input("Enter number:"))
if num>1:
    for i in range(2,num):
        if num%i==0:
            print("Not Prime")
            break
    else:
        print("Prime")
else:
    print("Not Prime")
# Out:
# Enter number: 11
# Prime

# %%
#Exp 9

p = float(input("Principal:"))
r = float(input("Rate:"))
t = float(input("Time:"))
si = (p*r*t)/100
ci = p*((1+r/100)**t)-p
print("SI:",si)
print("CI:",ci)
# Out:
# Principal: 10000
# Rate: 5
# Time: 4
# SI: 2000.0
# CI: 2155.062500000002

# %%
#Exp 10

marks = [80, 70, 90]
marks.append(85)
marks[1] = 75
marks.remove(90)
print(marks)
# Out:
# [80, 75, 85]

# %%
#Exp 11

emp = {"ID":101, "Name":"Aman", "Salary":80000}
print(emp)
# Out:
# {'ID': 101, 'Name': 'Aman', 'Salary': 80000}

# %%
#Exp 12

emps = {101:"Aman", 102:"Rohit"}
id = int(input("Enter ID:"))
print(emps.get(id, "Not found"))
# Out:
# Enter ID: 101
# Aman

# %%
#Exp 13

emp = {"Rahul":50000,"Aman":40000,"Neha":60000}
sorted_emp = sorted(emp.items(),key=lambda x:x[1])
print(sorted_emp)
# Out:
# [('Aman', 40000), ('Rahul', 50000), ('Neha', 60000)]

# %%
#Exp 14

lst = [1,2,2,3,4,4]
unique = list(set(lst))
print(unique)
# Out:
# [1, 2, 3, 4]

# %%
#Exp 15

s = input("Enter string: ")
v = c = d = sp = 0
for ch in s:
    if ch.isalpha():
        if ch.lower() in 'aeiou':
            v += 1
        else:
            c += 1
    elif ch.isdigit():
        d += 1
else: 
    sp += 1
print(v,c,d,sp)
# Out:
# Enter string:  Aman
# 2 2 0 1

# %%
#Exp 17

try:
    a = int(input())
    b = int(input())
    print(a/b)
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
#  5
#  4
# 1.25
